# %%
import requests

r = requests.get('https://api.github.com/events')
# requisicao get 
# cliente -> request -> servidor
# servidor -> response -> cliente
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.json()
# Out:
# [{'id': '30430188634',
#   'type': 'PushEvent',
#   'actor': {'id': 81948346,
#    'login': 'anikdhabal',
#    'display_login': 'anikdhabal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anikdhabal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81948346?'},
#   'repo': {'id': 641526640,
#    'name': 'anikdhabal/jaeger-ui',
#    'url': 'https://api.github.com/repos/anikdhabal/jaeger-ui'},
#   'payload': {'repository_id': 641526640,
#    'push_id': 14322960156,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/issue#1332',
#    'head': 'fe2335b6f2a639e9e7559b40c7f3904c7d2d6328',
#    'before': 'd3bf169f4407fea87794736feb7ebcfc78988638',
#    'commits': [{'sha': 'fe2335b6f2a639e9e7559b40c7f3904c7d2d6328',
#      'author': {'email': '81948346+anikdhabal@users.noreply.github.com',
#       'name': 'Anik Dhabal Babu'},
#      'message': 'Update utils.tsx\n\nSigned-off-by: Anik Dhabal Babu <81948346+anikdhabal@users.noreply.github.com>',
# ...

# %%
# endpoints
#Os endpoints são partes da URL que precisamos modificar para acessar informações específicas de uma API. 
#Para ilustrar melhor, vamos revisitar o código inicial da nossa requisição GET usando o requests.get,
#onde passamos a URL para obter informações sobre os eventos.

# %%
r = requests.get('https://api.github.com/versions')
r.json()
# Out:
# ['2022-11-28']

# %%
r = requests.get('https://api.github.com/users/alineralncs')
r.status_code
r.json()
# Out:
# {'login': 'alineralncs',
#  'id': 38014924,
#  'node_id': 'MDQ6VXNlcjM4MDE0OTI0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/38014924?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/alineralncs',
#  'html_url': 'https://github.com/alineralncs',
#  'followers_url': 'https://api.github.com/users/alineralncs/followers',
#  'following_url': 'https://api.github.com/users/alineralncs/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/alineralncs/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/alineralncs/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/alineralncs/subscriptions',
#  'organizations_url': 'https://api.github.com/users/alineralncs/orgs',
#  'repos_url': 'https://api.github.com/users/alineralncs/repos',
#  'events_url': 'https://api.github.com/users/alineralncs/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/alineralncs/received_events',
# ...
